# %%
# %pwd
# Out:
# 'd:\\LEARN\\DJANGO\\diamond-web-clone\\notebook'

# %%
# %cd ..
# %cd diamond-web-clone 
# %pwd
# Out:
# 'd:\\LEARN\\DJANGO\\diamond-web-clone'

# %%
# !python check_env.py
# Out:
# 🚀 Memulai Diagnostic Project Diamond-Web...
# ==================================================
#
#  1. Cek Struktur Folder
# Root Project: ✅ OK
# App Folder: ✅ OK
# Config Folder: ✅ OK
# Templates Folder: ❌ ERROR
#     Detail: Folder 'templates' tidak ada (mungkin typo 'tamplate'?)
#
# 🐍 2. Cek Python Environment
#    Python Path: d:\LEARN\DJANGO\diamond-web-clone\.venv\Scripts\python.exe
# Virtual Env: ✅ OK
#
# 📦 3. Cek Instalasi Django
# Django Import: ❌ ERROR
#     Detail: Django belum terinstall di environment ini. Jalankan: pip install django

# %%
# Actifkan virtual environtment 
# !.venv\Scripts\activate

# %%
# !python -c "import sys; print(sys.executable)"
# Out:
# C:\Users\mujir\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe

# %%
# !python manage.py check 
# !python manage.py runserver 

# Akses: http://localhost:8000 atau http://127.0.0.1:8000C
# Out:
# System check identified no issues (0 silenced).
# CommandError: You must set settings.ALLOWED_HOSTS if DEBUG is False.
